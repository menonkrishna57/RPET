# %% [markdown]
# Om Patel I044

# %% [markdown]
# To highlight edges for the given image and draw histogram

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from skimage import data

# %%
image = data.brick()
[rw, col] = image.shape
plt.imshow(image)

# %%
diffx = cv2.Sobel(image, ddepth=cv2.CV_32F, dx=1, dy=1, ksize=3) #32 floating points
diffy = cv2.Sobel(image, ddepth=cv2.CV_32F, dx=0, dy=1, ksize=3)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].imshow(image, cmap='gray')
axes[0].set_title('original image')

axes[1].imshow(diffx_abs, cmap='gray')
axes[1].set_title('Sobel X')

axes[2].imshow(diffy_abs, cmap='gray')
axes[2].set_title('Sobel Y')
# Out:
# Text(0.5, 1.0, 'Sobel Y')

# %%
diffx_abs = cv2.convertScaleAbs(diffx)
diffy_abs = cv2.convertScaleAbs(diffy)

# %%
mag = np.sqrt(diffx**2 + diffy**2)
ang = ((np.arctan2(diffy, diffx)) * 180 / np.pi) % 180
